# %% [markdown]
# # CellChat

# %%
# install.packages("Seurat")

# # install.packages("devtools")
# BiocManager::install("BiocNeighbors")
# # devtools::install_github("hadley/devtools")

# install.packages('NMF')
# devtools::install_github("jokergoo/circlize")
# devtools::install_github("jokergoo/ComplexHeatmap")

# devtools::install_github("sqjin/CellChat")

# %%
# # in py console
# pip install umap-learn

# %%
library(Seurat)
library(ggplot2)
library(dplyr)
library(magrittr)
library(CellChat)              
library(patchwork)
library(igraph)
# Out:
# Warning message:
# “пакет ‘Seurat’ был собран под R версии 4.3.3”
# Загрузка требуемого пакета: SeuratObject
#
# Warning message:
# “пакет ‘SeuratObject’ был собран под R версии 4.3.3”
# Загрузка требуемого пакета: sp
#
# Warning message:
# “пакет ‘sp’ был собран под R версии 4.3.3”
# Registered S3 method overwritten by 'future':
#   method               from
#   all.equal.connection parallelly
#
#
# Присоединяю пакет: ‘SeuratObject’
#
#
# Следующие объекты скрыты от ‘package:base’:
#
#     intersect, t
#
#
# Warning message:
# “пакет ‘ggplot2’ был собран под R версии 4.3.3”
#
# Присоединяю пакет: ‘dplyr’
#
#
# Следующие объекты скрыты от ‘package:stats’:
#
#     filter, lag
#
#
# Следующие объекты скрыты от ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Загрузка требуемого пакета: igraph
#
# Warning message:
# “пакет ‘igraph’ был собран под R версии 4.3.3”
#
# Присоединяю пакет: ‘igraph’
#
#
# Следующие объекты скрыты от ‘package:dplyr’:
#
#     as_data_frame, groups, union
#
#
# Следующий объект скрыт от ‘package:Seurat’:
#
#     components
#
#
# Следующие объекты скрыты от ‘package:stats’:
#
#     decompose, spectrum
#
#
# Следующий объект скрыт от ‘package:base’:
#
#     union
#
#
# Warning message:
# “пакет ‘patchwork’ был собран под R версии 4.3.3”

# %%
# Multicore CPU usage activation - Future

library(future)

# plan("multicore", workers = 24) # Mac Pro 6.1
# plan(workers = 36) # iMac Pro 1.1
# plan("multicore", workers = 8) # 4 core Intel CPU and M1 have 8 threads
# plan("multicore", workers = 12) # 6 core Intel CPU has 12 threads
plan("multicore", workers = 10) # 10 core M1 Pro CPU has 10 threads

# Set RAM Size to 3/4 of total RAM

# options(future.globals.maxSize = 48000 * 1024^2) # Mac Pros have 64 Gb
options(future.globals.maxSize = 12000 * 1024^2) # iMacs and MacBook Pros have 16 Gb

future.seed = NULL # Removes future-generated statistical errors
# Out:
# Warning message:
# “пакет ‘future’ был собран под R версии 4.3.3”
#
# Присоединяю пакет: ‘future’
#
#
# Следующие объекты скрыты от ‘package:igraph’:
#
#     %->%, %<-%

# %%
# Seurat

Multimodal_seurat_object <- readRDS('Seurat_Clusters.rds')

# %%
Multimodal_seurat_object@meta.data
# Out:
#                                                 orig.ident
# Non-TD T-cells_Sample 1_26559                   Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_62766                   Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_70254                   Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_135684                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_144969                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_167076                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_175702                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_228916                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_241934                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_249685                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_298135                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_311295                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_340656                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_577028                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_596696                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_630123                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_652751                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_689952                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_731033                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_731940                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_759190                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_826755                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_884801                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_888336                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_911550                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_922194                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_978646                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_1001438                 Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_1036780                 Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_1038576                 Non-TD T-cells_Sample 1
# ⋮                                               ⋮
# anti-Her2:neu T-cells + Tumor_Sample 3_53078473 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53092988 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53186075 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53193581 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53244025 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53253326 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53266014 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53354567 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53426098 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53483713 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53502644 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53837593 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53842862 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53858747 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53898986 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53920687 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_54180771 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_54621600 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_54858972 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55108995 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55238187 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55282610 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55289964 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55582847 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55682159 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55875266 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55956089 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55976960 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_56075235 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_56254844 anti-Her2:neu T-cells + Tumor_Sample 3
#                                                 nCount_RNA nFeature_RNA
# Non-TD T-cells_Sample 1_26559                   1704       124
# Non-TD T-cells_Sample 1_62766                   2571       147
# Non-TD T-cells_Sample 1_70254                    639       107
# Non-TD T-cells_Sample 1_135684                   527        83
# Non-TD T-cells_Sample 1_144969                  1071       103
# Non-TD T-cells_Sample 1_167076                   703       103
# Non-TD T-cells_Sample 1_175702                  1209       128
# Non-TD T-cells_Sample 1_228916                   608        94
# Non-TD T-cells_Sample 1_241934                   575        71
# Non-TD T-cells_Sample 1_249685                  1615       119
# Non-TD T-cells_Sample 1_298135                   266        70
# Non-TD T-cells_Sample 1_311295                   708        82
# Non-TD T-cells_Sample 1_340656                  1180       115
# Non-TD T-cells_Sample 1_577028                   891        95
# Non-TD T-cells_Sample 1_596696                   551        91
# Non-TD T-cells_Sample 1_630123                   463        80
# Non-TD T-cells_Sample 1_652751                   380        86
# Non-TD T-cells_Sample 1_689952                   574        86
# Non-TD T-cells_Sample 1_731033                  1326       116
# Non-TD T-cells_Sample 1_731940                   531        72
# Non-TD T-cells_Sample 1_759190                  1758       128
# Non-TD T-cells_Sample 1_826755                   735        89
# Non-TD T-cells_Sample 1_884801                   851       101
# Non-TD T-cells_Sample 1_888336                   449        72
# Non-TD T-cells_Sample 1_911550                   510        84
# Non-TD T-cells_Sample 1_922194                   926        87
# Non-TD T-cells_Sample 1_978646                  1443       113
# Non-TD T-cells_Sample 1_1001438                  437        81
# Non-TD T-cells_Sample 1_1036780                 2459       134
# Non-TD T-cells_Sample 1_1038576                  285        66
# ⋮                                               ⋮          ⋮
# anti-Her2:neu T-cells + Tumor_Sample 3_53078473  333        85
# anti-Her2:neu T-cells + Tumor_Sample 3_53092988 1084       111
# anti-Her2:neu T-cells + Tumor_Sample 3_53186075  392        88
# anti-Her2:neu T-cells + Tumor_Sample 3_53193581  917       105
# anti-Her2:neu T-cells + Tumor_Sample 3_53244025  897        93
# anti-Her2:neu T-cells + Tumor_Sample 3_53253326  366        93
# anti-Her2:neu T-cells + Tumor_Sample 3_53266014  519        93
# anti-Her2:neu T-cells + Tumor_Sample 3_53354567  555        94
# anti-Her2:neu T-cells + Tumor_Sample 3_53426098  632       101
# anti-Her2:neu T-cells + Tumor_Sample 3_53483713  356        71
# anti-Her2:neu T-cells + Tumor_Sample 3_53502644  729       115
# anti-Her2:neu T-cells + Tumor_Sample 3_53837593  583        91
# anti-Her2:neu T-cells + Tumor_Sample 3_53842862  818       101
# anti-Her2:neu T-cells + Tumor_Sample 3_53858747 1061       114
# anti-Her2:neu T-cells + Tumor_Sample 3_53898986  821       109
# anti-Her2:neu T-cells + Tumor_Sample 3_53920687  844       111
# anti-Her2:neu T-cells + Tumor_Sample 3_54180771  645        94
# anti-Her2:neu T-cells + Tumor_Sample 3_54621600 1679       107
# anti-Her2:neu T-cells + Tumor_Sample 3_54858972  758        99
# anti-Her2:neu T-cells + Tumor_Sample 3_55108995  320        72
# anti-Her2:neu T-cells + Tumor_Sample 3_55238187  393        74
# anti-Her2:neu T-cells + Tumor_Sample 3_55282610  334        67
# anti-Her2:neu T-cells + Tumor_Sample 3_55289964  539        90
# anti-Her2:neu T-cells + Tumor_Sample 3_55582847  346        77
# anti-Her2:neu T-cells + Tumor_Sample 3_55682159 1015       109
# anti-Her2:neu T-cells + Tumor_Sample 3_55875266  486        82
# anti-Her2:neu T-cells + Tumor_Sample 3_55956089  814       114
# anti-Her2:neu T-cells + Tumor_Sample 3_55976960  407        77
# anti-Her2:neu T-cells + Tumor_Sample 3_56075235  416        82
# anti-Her2:neu T-cells + Tumor_Sample 3_56254844 2821       142
#                                                 nCount_ADT nFeature_ADT
# Non-TD T-cells_Sample 1_26559                   1620       15
# Non-TD T-cells_Sample 1_62766                   2376       15
# Non-TD T-cells_Sample 1_70254                   2383       15
# Non-TD T-cells_Sample 1_135684                  1531       14
# Non-TD T-cells_Sample 1_144969                  2972       15
# Non-TD T-cells_Sample 1_167076                  2289       15
# Non-TD T-cells_Sample 1_175702                   620       15
# Non-TD T-cells_Sample 1_228916                  3037       15
# Non-TD T-cells_Sample 1_241934                   967       15
# Non-TD T-cells_Sample 1_249685                  1146       15
# Non-TD T-cells_Sample 1_298135                   265       15
# Non-TD T-cells_Sample 1_311295                  2869       15
# Non-TD T-cells_Sample 1_340656                  3653       15
# Non-TD T-cells_Sample 1_577028                   711       15
# Non-TD T-cells_Sample 1_596696                  2793       14
# Non-TD T-cells_Sample 1_630123                  2124       15
# Non-TD T-cells_Sample 1_652751                   564       15
# Non-TD T-cells_Sample 1_689952                   925       15
# Non-TD T-cells_Sample 1_731033                  4244       15
# Non-TD T-cells_Sample 1_731940                   920       15
# Non-TD T-cells_Sample 1_759190                  1348       14
# Non-TD T-cells_Sample 1_826755                  1379       15
# Non-TD T-cells_Sample 1_884801                  3735       15
# Non-TD T-cells_Sample 1_888336                   923       15
# Non-TD T-cells_Sample 1_911550                   637       15
# Non-TD T-cells_Sample 1_922194                  2861       15
# Non-TD T-cells_Sample 1_978646                  2514       15
# Non-TD T-cells_Sample 1_1001438                 2167       15
# Non-TD T-cells_Sample 1_1036780                 1765       15
# Non-TD T-cells_Sample 1_1038576                  630       14
# ⋮                                               ⋮          ⋮
# anti-Her2:neu T-cells + Tumor_Sample 3_53078473  440       14
# anti-Her2:neu T-cells + Tumor_Sample 3_53092988 2195       15
# anti-Her2:neu T-cells + Tumor_Sample 3_53186075  923       14
# anti-Her2:neu T-cells + Tumor_Sample 3_53193581  702       15
# anti-Her2:neu T-cells + Tumor_Sample 3_53244025 2536       15
# anti-Her2:neu T-cells + Tumor_Sample 3_53253326  541       15
# anti-Her2:neu T-cells + Tumor_Sample 3_53266014  926       15
# anti-Her2:neu T-cells + Tumor_Sample 3_53354567  988       15
# anti-Her2:neu T-cells + Tumor_Sample 3_53426098  726       15
# anti-Her2:neu T-cells + Tumor_Sample 3_53483713  975       15
# anti-Her2:neu T-cells + Tumor_Sample 3_53502644 1980       15
# anti-Her2:neu T-cells + Tumor_Sample 3_53837593  702       15
# anti-Her2:neu T-cells + Tumor_Sample 3_53842862 2186       14
# anti-Her2:neu T-cells + Tumor_Sample 3_53858747 1663       15
# anti-Her2:neu T-cells + Tumor_Sample 3_53898986 1446       15
# anti-Her2:neu T-cells + Tumor_Sample 3_53920687 1975       15
# anti-Her2:neu T-cells + Tumor_Sample 3_54180771 1721       15
# anti-Her2:neu T-cells + Tumor_Sample 3_54621600 2395       14
# anti-Her2:neu T-cells + Tumor_Sample 3_54858972 1445       14
# anti-Her2:neu T-cells + Tumor_Sample 3_55108995 1043       15
# anti-Her2:neu T-cells + Tumor_Sample 3_55238187  643       15
# anti-Her2:neu T-cells + Tumor_Sample 3_55282610  594       15
# anti-Her2:neu T-cells + Tumor_Sample 3_55289964 1265       15
# anti-Her2:neu T-cells + Tumor_Sample 3_55582847  771       15
# anti-Her2:neu T-cells + Tumor_Sample 3_55682159 1264       15
# anti-Her2:neu T-cells + Tumor_Sample 3_55875266  361       13
# anti-Her2:neu T-cells + Tumor_Sample 3_55956089 1580       15
# anti-Her2:neu T-cells + Tumor_Sample 3_55976960 1125       15
# anti-Her2:neu T-cells + Tumor_Sample 3_56075235 1182       15
# anti-Her2:neu T-cells + Tumor_Sample 3_56254844 1800       15
#                                                 Group
# Non-TD T-cells_Sample 1_26559                   Non-TD T-cells
# Non-TD T-cells_Sample 1_62766                   Non-TD T-cells
# Non-TD T-cells_Sample 1_70254                   Non-TD T-cells
# Non-TD T-cells_Sample 1_135684                  Non-TD T-cells
# Non-TD T-cells_Sample 1_144969                  Non-TD T-cells
# Non-TD T-cells_Sample 1_167076                  Non-TD T-cells
# Non-TD T-cells_Sample 1_175702                  Non-TD T-cells
# Non-TD T-cells_Sample 1_228916                  Non-TD T-cells
# Non-TD T-cells_Sample 1_241934                  Non-TD T-cells
# Non-TD T-cells_Sample 1_249685                  Non-TD T-cells
# Non-TD T-cells_Sample 1_298135                  Non-TD T-cells
# Non-TD T-cells_Sample 1_311295                  Non-TD T-cells
# Non-TD T-cells_Sample 1_340656                  Non-TD T-cells
# Non-TD T-cells_Sample 1_577028                  Non-TD T-cells
# Non-TD T-cells_Sample 1_596696                  Non-TD T-cells
# Non-TD T-cells_Sample 1_630123                  Non-TD T-cells
# Non-TD T-cells_Sample 1_652751                  Non-TD T-cells
# Non-TD T-cells_Sample 1_689952                  Non-TD T-cells
# Non-TD T-cells_Sample 1_731033                  Non-TD T-cells
# Non-TD T-cells_Sample 1_731940                  Non-TD T-cells
# Non-TD T-cells_Sample 1_759190                  Non-TD T-cells
# Non-TD T-cells_Sample 1_826755                  Non-TD T-cells
# Non-TD T-cells_Sample 1_884801                  Non-TD T-cells
# Non-TD T-cells_Sample 1_888336                  Non-TD T-cells
# Non-TD T-cells_Sample 1_911550                  Non-TD T-cells
# Non-TD T-cells_Sample 1_922194                  Non-TD T-cells
# Non-TD T-cells_Sample 1_978646                  Non-TD T-cells
# Non-TD T-cells_Sample 1_1001438                 Non-TD T-cells
# Non-TD T-cells_Sample 1_1036780                 Non-TD T-cells
# Non-TD T-cells_Sample 1_1038576                 Non-TD T-cells
# ⋮                                               ⋮
# anti-Her2:neu T-cells + Tumor_Sample 3_53078473 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53092988 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53186075 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53193581 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53244025 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53253326 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53266014 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53354567 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53426098 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53483713 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53502644 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53837593 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53842862 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53858747 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53898986 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_53920687 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_54180771 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_54621600 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_54858972 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_55108995 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_55238187 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_55282610 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_55289964 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_55582847 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_55682159 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_55875266 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_55956089 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_55976960 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_56075235 anti-Her2:neu T-cells + Tumor
# anti-Her2:neu T-cells + Tumor_Sample 3_56254844 anti-Her2:neu T-cells + Tumor
#                                                 Sample
# Non-TD T-cells_Sample 1_26559                   Sample 1
# Non-TD T-cells_Sample 1_62766                   Sample 1
# Non-TD T-cells_Sample 1_70254                   Sample 1
# Non-TD T-cells_Sample 1_135684                  Sample 1
# Non-TD T-cells_Sample 1_144969                  Sample 1
# Non-TD T-cells_Sample 1_167076                  Sample 1
# Non-TD T-cells_Sample 1_175702                  Sample 1
# Non-TD T-cells_Sample 1_228916                  Sample 1
# Non-TD T-cells_Sample 1_241934                  Sample 1
# Non-TD T-cells_Sample 1_249685                  Sample 1
# Non-TD T-cells_Sample 1_298135                  Sample 1
# Non-TD T-cells_Sample 1_311295                  Sample 1
# Non-TD T-cells_Sample 1_340656                  Sample 1
# Non-TD T-cells_Sample 1_577028                  Sample 1
# Non-TD T-cells_Sample 1_596696                  Sample 1
# Non-TD T-cells_Sample 1_630123                  Sample 1
# Non-TD T-cells_Sample 1_652751                  Sample 1
# Non-TD T-cells_Sample 1_689952                  Sample 1
# Non-TD T-cells_Sample 1_731033                  Sample 1
# Non-TD T-cells_Sample 1_731940                  Sample 1
# Non-TD T-cells_Sample 1_759190                  Sample 1
# Non-TD T-cells_Sample 1_826755                  Sample 1
# Non-TD T-cells_Sample 1_884801                  Sample 1
# Non-TD T-cells_Sample 1_888336                  Sample 1
# Non-TD T-cells_Sample 1_911550                  Sample 1
# Non-TD T-cells_Sample 1_922194                  Sample 1
# Non-TD T-cells_Sample 1_978646                  Sample 1
# Non-TD T-cells_Sample 1_1001438                 Sample 1
# Non-TD T-cells_Sample 1_1036780                 Sample 1
# Non-TD T-cells_Sample 1_1038576                 Sample 1
# ⋮                                               ⋮
# anti-Her2:neu T-cells + Tumor_Sample 3_53078473 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53092988 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53186075 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53193581 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53244025 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53253326 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53266014 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53354567 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53426098 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53483713 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53502644 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53837593 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53842862 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53858747 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53898986 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53920687 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_54180771 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_54621600 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_54858972 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55108995 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55238187 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55282610 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55289964 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55582847 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55682159 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55875266 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55956089 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55976960 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_56075235 Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_56254844 Sample 3
#                                                 Batch
# Non-TD T-cells_Sample 1_26559                   Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_62766                   Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_70254                   Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_135684                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_144969                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_167076                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_175702                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_228916                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_241934                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_249685                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_298135                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_311295                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_340656                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_577028                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_596696                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_630123                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_652751                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_689952                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_731033                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_731940                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_759190                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_826755                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_884801                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_888336                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_911550                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_922194                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_978646                  Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_1001438                 Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_1036780                 Non-TD T-cells_Sample 1
# Non-TD T-cells_Sample 1_1038576                 Non-TD T-cells_Sample 1
# ⋮                                               ⋮
# anti-Her2:neu T-cells + Tumor_Sample 3_53078473 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53092988 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53186075 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53193581 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53244025 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53253326 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53266014 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53354567 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53426098 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53483713 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53502644 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53837593 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53842862 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53858747 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53898986 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53920687 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_54180771 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_54621600 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_54858972 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55108995 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55238187 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55282610 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55289964 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55582847 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55682159 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55875266 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55956089 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55976960 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_56075235 anti-Her2:neu T-cells + Tumor_Sample 3
# anti-Her2:neu T-cells + Tumor_Sample 3_56254844 anti-Her2:neu T-cells + Tumor_Sample 3
#                                                 nCount_SCT nFeature_SCT
# Non-TD T-cells_Sample 1_26559                   782        100
# Non-TD T-cells_Sample 1_62766                   800        113
# Non-TD T-cells_Sample 1_70254                   753        107
# Non-TD T-cells_Sample 1_135684                  756         83
# Non-TD T-cells_Sample 1_144969                  786        103
# Non-TD T-cells_Sample 1_167076                  760        103
# Non-TD T-cells_Sample 1_175702                  799        127
# Non-TD T-cells_Sample 1_228916                  758         94
# Non-TD T-cells_Sample 1_241934                  674         72
# Non-TD T-cells_Sample 1_249685                  790         97
# Non-TD T-cells_Sample 1_298135                  714         82
# Non-TD T-cells_Sample 1_311295                  760         80
# Non-TD T-cells_Sample 1_340656                  798        114
# Non-TD T-cells_Sample 1_577028                  790         95
# Non-TD T-cells_Sample 1_596696                  751         91
# Non-TD T-cells_Sample 1_630123                  760         80
# Non-TD T-cells_Sample 1_652751                  740         87
# Non-TD T-cells_Sample 1_689952                  761         86
# Non-TD T-cells_Sample 1_731033                  797        113
# Non-TD T-cells_Sample 1_731940                  756         71
# Non-TD T-cells_Sample 1_759190                  788         91
# Non-TD T-cells_Sample 1_826755                  764         88
# Non-TD T-cells_Sample 1_884801                  790        101
# Non-TD T-cells_Sample 1_888336                  747         72
# Non-TD T-cells_Sample 1_911550                  756         83
# Non-TD T-cells_Sample 1_922194                  787         87
# Non-TD T-cells_Sample 1_978646                  795         96
# Non-TD T-cells_Sample 1_1001438                 748         81
# Non-TD T-cells_Sample 1_1036780                 789         99
# Non-TD T-cells_Sample 1_1038576                 729         72
# ⋮                                               ⋮          ⋮
# anti-Her2:neu T-cells + Tumor_Sample 3_53078473 648         85
# anti-Her2:neu T-cells + Tumor_Sample 3_53092988 695        109
# anti-Her2:neu T-cells + Tumor_Sample 3_53186075 660         89
# anti-Her2:neu T-cells + Tumor_Sample 3_53193581 685        105
# anti-Her2:neu T-cells + Tumor_Sample 3_53244025 678         93
# anti-Her2:neu T-cells + Tumor_Sample 3_53253326 648         93
# anti-Her2:neu T-cells + Tumor_Sample 3_53266014 658         93
# anti-Her2:neu T-cells + Tumor_Sample 3_53354567 659         94
# anti-Her2:neu T-cells + Tumor_Sample 3_53426098 658        101
# anti-Her2:neu T-cells + Tumor_Sample 3_53483713 647         71
# anti-Her2:neu T-cells + Tumor_Sample 3_53502644 684        115
# anti-Her2:neu T-cells + Tumor_Sample 3_53837593 655         91
# anti-Her2:neu T-cells + Tumor_Sample 3_53842862 682        101
# anti-Her2:neu T-cells + Tumor_Sample 3_53858747 692        113
# anti-Her2:neu T-cells + Tumor_Sample 3_53898986 682        109
# anti-Her2:neu T-cells + Tumor_Sample 3_53920687 681        109
# anti-Her2:neu T-cells + Tumor_Sample 3_54180771 658         94
# anti-Her2:neu T-cells + Tumor_Sample 3_54621600 690         84
# anti-Her2:neu T-cells + Tumor_Sample 3_54858972 681         99
# anti-Her2:neu T-cells + Tumor_Sample 3_55108995 631         73
# anti-Her2:neu T-cells + Tumor_Sample 3_55238187 649         75
# anti-Her2:neu T-cells + Tumor_Sample 3_55282610 637         71
# anti-Her2:neu T-cells + Tumor_Sample 3_55289964 655         89
# anti-Her2:neu T-cells + Tumor_Sample 3_55582847 642         80
# anti-Her2:neu T-cells + Tumor_Sample 3_55682159 690        108
# anti-Her2:neu T-cells + Tumor_Sample 3_55875266 649         82
# anti-Her2:neu T-cells + Tumor_Sample 3_55956089 683        113
# anti-Her2:neu T-cells + Tumor_Sample 3_55976960 660         77
# anti-Her2:neu T-cells + Tumor_Sample 3_56075235 653         82
# anti-Her2:neu T-cells + Tumor_Sample 3_56254844 685         99
#                                                 SCT.weight   ADT.weight
# Non-TD T-cells_Sample 1_26559                   7.580087e-03 0.99241991
# Non-TD T-cells_Sample 1_62766                   2.227180e-03 0.99777282
# Non-TD T-cells_Sample 1_70254                   1.106141e-06 0.99999889
# Non-TD T-cells_Sample 1_135684                  1.434172e-27 1.00000000
# Non-TD T-cells_Sample 1_144969                  8.023335e-16 1.00000000
# Non-TD T-cells_Sample 1_167076                  2.727234e-01 0.72727663
# Non-TD T-cells_Sample 1_175702                  9.851140e-01 0.01488604
# Non-TD T-cells_Sample 1_228916                  5.709889e-01 0.42901105
# Non-TD T-cells_Sample 1_241934                  2.106646e-03 0.99789335
# Non-TD T-cells_Sample 1_249685                  2.175753e-04 0.99978242
# Non-TD T-cells_Sample 1_298135                  1.485431e-16 1.00000000
# Non-TD T-cells_Sample 1_311295                  6.759809e-04 0.99932402
# Non-TD T-cells_Sample 1_340656                  1.428463e-01 0.85715369
# Non-TD T-cells_Sample 1_577028                  5.913944e-02 0.94086056
# Non-TD T-cells_Sample 1_596696                  1.394164e-01 0.86058361
# Non-TD T-cells_Sample 1_630123                  2.101159e-04 0.99978988
# Non-TD T-cells_Sample 1_652751                  1.377162e-03 0.99862284
# Non-TD T-cells_Sample 1_689952                  4.641317e-09 1.00000000
# Non-TD T-cells_Sample 1_731033                  4.685997e-07 0.99999953
# Non-TD T-cells_Sample 1_731940                  1.171655e-02 0.98828345
# Non-TD T-cells_Sample 1_759190                  1.404289e-19 1.00000000
# Non-TD T-cells_Sample 1_826755                  7.746648e-02 0.92253352
# Non-TD T-cells_Sample 1_884801                  3.717571e-02 0.96282429
# Non-TD T-cells_Sample 1_888336                  4.773539e-01 0.52264606
# Non-TD T-cells_Sample 1_911550                  1.441168e-35 1.00000000
# Non-TD T-cells_Sample 1_922194                  3.723201e-01 0.62767994
# Non-TD T-cells_Sample 1_978646                  2.661426e-02 0.97338574
# Non-TD T-cells_Sample 1_1001438                 1.916347e-01 0.80836530
# Non-TD T-cells_Sample 1_1036780                 1.654181e-04 0.99983458
# Non-TD T-cells_Sample 1_1038576                 1.091981e-04 0.99989080
# ⋮                                               ⋮            ⋮
# anti-Her2:neu T-cells + Tumor_Sample 3_53078473 8.888977e-06 0.9999911
# anti-Her2:neu T-cells + Tumor_Sample 3_53092988 5.014176e-03 0.9949858
# anti-Her2:neu T-cells + Tumor_Sample 3_53186075 9.369244e-03 0.9906308
# anti-Her2:neu T-cells + Tumor_Sample 3_53193581 5.024186e-01 0.4975814
# anti-Her2:neu T-cells + Tumor_Sample 3_53244025 9.248779e-02 0.9075122
# anti-Her2:neu T-cells + Tumor_Sample 3_53253326 1.496862e-13 1.0000000
# anti-Her2:neu T-cells + Tumor_Sample 3_53266014 1.237102e-03 0.9987629
# anti-Her2:neu T-cells + Tumor_Sample 3_53354567 2.196085e-01 0.7803915
# anti-Her2:neu T-cells + Tumor_Sample 3_53426098 1.130998e-01 0.8869002
# anti-Her2:neu T-cells + Tumor_Sample 3_53483713 2.708942e-85 1.0000000
# anti-Her2:neu T-cells + Tumor_Sample 3_53502644 1.000752e-02 0.9899925
# anti-Her2:neu T-cells + Tumor_Sample 3_53837593 6.688331e-05 0.9999331
# anti-Her2:neu T-cells + Tumor_Sample 3_53842862 6.629999e-01 0.3370001
# anti-Her2:neu T-cells + Tumor_Sample 3_53858747 8.759098e-01 0.1240902
# anti-Her2:neu T-cells + Tumor_Sample 3_53898986 1.928704e-03 0.9980713
# anti-Her2:neu T-cells + Tumor_Sample 3_53920687 6.377567e-02 0.9362243
# anti-Her2:neu T-cells + Tumor_Sample 3_54180771 2.174104e-01 0.7825896
# anti-Her2:neu T-cells + Tumor_Sample 3_54621600 8.571901e-03 0.9914281
# anti-Her2:neu T-cells + Tumor_Sample 3_54858972 1.271349e-13 1.0000000
# anti-Her2:neu T-cells + Tumor_Sample 3_55108995 1.316246e-09 1.0000000
# anti-Her2:neu T-cells + Tumor_Sample 3_55238187 2.379561e-02 0.9762044
# anti-Her2:neu T-cells + Tumor_Sample 3_55282610 2.797757e-01 0.7202243
# anti-Her2:neu T-cells + Tumor_Sample 3_55289964 2.024638e-01 0.7975362
# anti-Her2:neu T-cells + Tumor_Sample 3_55582847 3.344316e-01 0.6655684
# anti-Her2:neu T-cells + Tumor_Sample 3_55682159 1.211623e-03 0.9987884
# anti-Her2:neu T-cells + Tumor_Sample 3_55875266 2.266914e-01 0.7733086
# anti-Her2:neu T-cells + Tumor_Sample 3_55956089 1.975873e-02 0.9802413
# anti-Her2:neu T-cells + Tumor_Sample 3_55976960 7.663985e-03 0.9923360
# anti-Her2:neu T-cells + Tumor_Sample 3_56075235 5.997071e-02 0.9400293
# anti-Her2:neu T-cells + Tumor_Sample 3_56254844 4.358238e-04 0.9995642
#                                                 wsnn_res.0.36 seurat_clusters
# Non-TD T-cells_Sample 1_26559                   2             2
# Non-TD T-cells_Sample 1_62766                   2             2
# Non-TD T-cells_Sample 1_70254                   0             0
# Non-TD T-cells_Sample 1_135684                  0             0
# Non-TD T-cells_Sample 1_144969                  0             0
# Non-TD T-cells_Sample 1_167076                  0             0
# Non-TD T-cells_Sample 1_175702                  7             7
# Non-TD T-cells_Sample 1_228916                  0             0
# Non-TD T-cells_Sample 1_241934                  2             2
# Non-TD T-cells_Sample 1_249685                  2             2
# Non-TD T-cells_Sample 1_298135                  1             1
# Non-TD T-cells_Sample 1_311295                  3             3
# Non-TD T-cells_Sample 1_340656                  0             0
# Non-TD T-cells_Sample 1_577028                  5             5
# Non-TD T-cells_Sample 1_596696                  3             3
# Non-TD T-cells_Sample 1_630123                  0             0
# Non-TD T-cells_Sample 1_652751                  1             1
# Non-TD T-cells_Sample 1_689952                  1             1
# Non-TD T-cells_Sample 1_731033                  4             4
# Non-TD T-cells_Sample 1_731940                  2             2
# Non-TD T-cells_Sample 1_759190                  0             0
# Non-TD T-cells_Sample 1_826755                  4             4
# Non-TD T-cells_Sample 1_884801                  0             0
# Non-TD T-cells_Sample 1_888336                  8             8
# Non-TD T-cells_Sample 1_911550                  6             6
# Non-TD T-cells_Sample 1_922194                  0             0
# Non-TD T-cells_Sample 1_978646                  5             5
# Non-TD T-cells_Sample 1_1001438                 0             0
# Non-TD T-cells_Sample 1_1036780                 4             4
# Non-TD T-cells_Sample 1_1038576                 3             3
# ⋮                                               ⋮             ⋮
# anti-Her2:neu T-cells + Tumor_Sample 3_53078473 1             1
# anti-Her2:neu T-cells + Tumor_Sample 3_53092988 3             3
# anti-Her2:neu T-cells + Tumor_Sample 3_53186075 1             1
# anti-Her2:neu T-cells + Tumor_Sample 3_53193581 8             8
# anti-Her2:neu T-cells + Tumor_Sample 3_53244025 3             3
# anti-Her2:neu T-cells + Tumor_Sample 3_53253326 8             8
# anti-Her2:neu T-cells + Tumor_Sample 3_53266014 8             8
# anti-Her2:neu T-cells + Tumor_Sample 3_53354567 8             8
# anti-Her2:neu T-cells + Tumor_Sample 3_53426098 6             6
# anti-Her2:neu T-cells + Tumor_Sample 3_53483713 1             1
# anti-Her2:neu T-cells + Tumor_Sample 3_53502644 1             1
# anti-Her2:neu T-cells + Tumor_Sample 3_53837593 9             9
# anti-Her2:neu T-cells + Tumor_Sample 3_53842862 0             0
# anti-Her2:neu T-cells + Tumor_Sample 3_53858747 4             4
# anti-Her2:neu T-cells + Tumor_Sample 3_53898986 2             2
# anti-Her2:neu T-cells + Tumor_Sample 3_53920687 0             0
# anti-Her2:neu T-cells + Tumor_Sample 3_54180771 1             1
# anti-Her2:neu T-cells + Tumor_Sample 3_54621600 3             3
# anti-Her2:neu T-cells + Tumor_Sample 3_54858972 1             1
# anti-Her2:neu T-cells + Tumor_Sample 3_55108995 10            10
# anti-Her2:neu T-cells + Tumor_Sample 3_55238187 8             8
# anti-Her2:neu T-cells + Tumor_Sample 3_55282610 6             6
# anti-Her2:neu T-cells + Tumor_Sample 3_55289964 1             1
# anti-Her2:neu T-cells + Tumor_Sample 3_55582847 1             1
# anti-Her2:neu T-cells + Tumor_Sample 3_55682159 1             1
# anti-Her2:neu T-cells + Tumor_Sample 3_55875266 6             6
# anti-Her2:neu T-cells + Tumor_Sample 3_55956089 3             3
# anti-Her2:neu T-cells + Tumor_Sample 3_55976960 10            10
# anti-Her2:neu T-cells + Tumor_Sample 3_56075235 10            10
# anti-Her2:neu T-cells + Tumor_Sample 3_56254844 8             8
#                                                 cluster_merged
# Non-TD T-cells_Sample 1_26559                   2
# Non-TD T-cells_Sample 1_62766                   2
# Non-TD T-cells_Sample 1_70254                   0
# Non-TD T-cells_Sample 1_135684                  0
# Non-TD T-cells_Sample 1_144969                  0
# Non-TD T-cells_Sample 1_167076                  0
# Non-TD T-cells_Sample 1_175702                  7
# Non-TD T-cells_Sample 1_228916                  0
# Non-TD T-cells_Sample 1_241934                  2
# Non-TD T-cells_Sample 1_249685                  2
# Non-TD T-cells_Sample 1_298135                  1
# Non-TD T-cells_Sample 1_311295                  3
# Non-TD T-cells_Sample 1_340656                  0
# Non-TD T-cells_Sample 1_577028                  5
# Non-TD T-cells_Sample 1_596696                  3
# Non-TD T-cells_Sample 1_630123                  0
# Non-TD T-cells_Sample 1_652751                  1
# Non-TD T-cells_Sample 1_689952                  1
# Non-TD T-cells_Sample 1_731033                  4
# Non-TD T-cells_Sample 1_731940                  2
# Non-TD T-cells_Sample 1_759190                  0
# Non-TD T-cells_Sample 1_826755                  4
# Non-TD T-cells_Sample 1_884801                  0
# Non-TD T-cells_Sample 1_888336                  8
# Non-TD T-cells_Sample 1_911550                  6
# Non-TD T-cells_Sample 1_922194                  0
# Non-TD T-cells_Sample 1_978646                  5
# Non-TD T-cells_Sample 1_1001438                 0
# Non-TD T-cells_Sample 1_1036780                 4
# Non-TD T-cells_Sample 1_1038576                 3
# ⋮                                               ⋮
# anti-Her2:neu T-cells + Tumor_Sample 3_53078473 1
# anti-Her2:neu T-cells + Tumor_Sample 3_53092988 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53186075 1
# anti-Her2:neu T-cells + Tumor_Sample 3_53193581 8
# anti-Her2:neu T-cells + Tumor_Sample 3_53244025 3
# anti-Her2:neu T-cells + Tumor_Sample 3_53253326 8
# anti-Her2:neu T-cells + Tumor_Sample 3_53266014 8
# anti-Her2:neu T-cells + Tumor_Sample 3_53354567 8
# anti-Her2:neu T-cells + Tumor_Sample 3_53426098 6
# anti-Her2:neu T-cells + Tumor_Sample 3_53483713 1
# anti-Her2:neu T-cells + Tumor_Sample 3_53502644 1
# anti-Her2:neu T-cells + Tumor_Sample 3_53837593 9
# anti-Her2:neu T-cells + Tumor_Sample 3_53842862 0
# anti-Her2:neu T-cells + Tumor_Sample 3_53858747 4
# anti-Her2:neu T-cells + Tumor_Sample 3_53898986 2
# anti-Her2:neu T-cells + Tumor_Sample 3_53920687 0
# anti-Her2:neu T-cells + Tumor_Sample 3_54180771 1
# anti-Her2:neu T-cells + Tumor_Sample 3_54621600 3
# anti-Her2:neu T-cells + Tumor_Sample 3_54858972 1
# anti-Her2:neu T-cells + Tumor_Sample 3_55108995 10
# anti-Her2:neu T-cells + Tumor_Sample 3_55238187 8
# anti-Her2:neu T-cells + Tumor_Sample 3_55282610 6
# anti-Her2:neu T-cells + Tumor_Sample 3_55289964 1
# anti-Her2:neu T-cells + Tumor_Sample 3_55582847 1
# anti-Her2:neu T-cells + Tumor_Sample 3_55682159 1
# anti-Her2:neu T-cells + Tumor_Sample 3_55875266 6
# anti-Her2:neu T-cells + Tumor_Sample 3_55956089 3
# anti-Her2:neu T-cells + Tumor_Sample 3_55976960 10
# anti-Her2:neu T-cells + Tumor_Sample 3_56075235 10
# anti-Her2:neu T-cells + Tumor_Sample 3_56254844 8

# %%
# Subset on a value in the object meta data
CellChat_T <- subset(x = Multimodal_seurat_object, 
                      subset = Group == "anti-Her2:neu T-cells + Tumor")

# %%
CellChat_T <- createCellChat(CellChat_T,
#                               group.by = 'Sample',
                              assay = 'SCT',
                              do.sparse = T)

CellChatDB <- CellChatDB.human

CellChatDB.use <- CellChatDB
CellChat_T@DB <- CellChatDB.use
CellChat_T <- subsetData(CellChat_T)
CellChat_T <- identifyOverExpressedGenes(CellChat_T)
CellChat_T <- identifyOverExpressedInteractions(CellChat_T)

CellChat_T <- projectData(CellChat_T, PPI.human)

CellChat_T <- computeCommunProb(CellChat_T)

CellChat_T <- computeCommunProbPathway(CellChat_T)

CellChat_T <- aggregateNet(CellChat_T)

library(NMF)
library(ggalluvial)
# Out:
# [1] "Create a CellChat object from a Seurat object"
# Warning message:
# “The `slot` argument of `GetAssayData()` is deprecated as of SeuratObject 5.0.0.
# ℹ Please use the `layer` argument instead.
# ℹ The deprecated feature was likely used in the CellChat package.
#   Please report the issue to the authors.”
# The `meta.data` slot in the Seurat object is used as cell meta information
# Set cell identities for the new CellChat object
# The cell groups used for CellChat analysis are  CD8 Naïve CD8 CM CD8 TEM CD8 Teff CD4 Naïve CD4 CM CD4 FH CD4 Th17 CD4 Treg γδ NKT
# triMean is used for calculating the average gene expression per cell group.
# [1] ">>> Run CellChat on sc/snRNA-seq data <<< [2025-10-18 14:51:58.715731]"
# [1] ">>> CellChat inference is done. Parameter values are stored in `object@options$parameter` <<< [2025-10-18 14:52:27.000264]"
# Warning message:
# “пакет ‘NMF’ был собран под R версии 4.3.3”
# Загрузка требуемого пакета: registry
#
# Загрузка требуемого пакета: rngtools
#
# Загрузка требуемого пакета: cluster
#
# NMF - BioConductor layer [OK] | Shared memory capabilities [NO: bigmemory] | Cores 2/2
#
#   To enable shared memory capabilities, try: install.extras('
# NMF
# ')
#
#
# Присоединяю пакет: ‘NMF’
#
#
# Следующий объект скрыт от ‘package:future’:
#
#     run
#
#
# Следующие объекты скрыты от ‘package:igraph’:
#
#     algorithm, compare

# %%
# selectK(CellChat_T, pattern = "outgoing")

# %%
# selectK(CellChat_T, pattern = "incoming")

# %%
nPatterns = 4
CellChat_T <- identifyCommunicationPatterns(CellChat_T, 
                                          pattern = "outgoing", 
                                          k = nPatterns)
nPatterns = 6
CellChat_T <- identifyCommunicationPatterns(CellChat_T, 
                                          pattern = "incoming", 
                                          k = nPatterns)
# Out:
# plot without title

# %%
CellChat_T@netP$pathways
# Out:
#  [1] "MHC-I"  "MHC-II" "ICAM"   "LCK"    "CCL"    "ITGB2"  "SELPLG" "CXCL"
#  [9] "CD70"   "CLEC"   "LT"     "CD48"   "TNF"    "SPP1"   "PECAM1"

# %%
pathways.show <- c("MHC-II") 

# Heatmap
par(mfrow=c(1,1))
netVisual_heatmap(CellChat_T, signaling = pathways.show, color.heatmap = "Reds")
#> Do heatmap based on a single object
# Out:
# Do heatmap based on a single object
# plot without title

# %%
# Chord diagram
pairLR <- extractEnrichedLR(CellChat_T, signaling = pathways.show, geneLR.return = FALSE)
LR.show <- pairLR[1,] # show one ligand-receptor pair
netVisual_individual(CellChat_T, signaling = pathways.show, pairLR.use = LR.show, layout = "chord")
# Out:
# [[1]]
# plot without title

# %%
# show all the significant interactions (L-R pairs) from some cell groups (defined by 'sources.use') to other cell groups (defined by 'targets.use')
netVisual_bubble(CellChat_T, sources.use = 10, remove.isolate = FALSE)
#> Comparing communications on a single object

ggsave( 
  "Dot Plot Outgoing MHC-II gd.png",
  plot   = last_plot(),
  width  = 15, 
  height = 18 ,
  units  = "cm",
  dpi    = 600,
  limitsize = TRUE,
  bg     = "white"
)
# Out:
# Comparing communications on a single object
# plot without title

# %%
# show all the significant interactions (L-R pairs) from some cell groups (defined by 'sources.use') to other cell groups (defined by 'targets.use')
netVisual_bubble(CellChat_T, sources.use = 11, remove.isolate = FALSE)
#> Comparing communications on a single object

ggsave( 
  "Dot Plot Outgoing MHC-II NKT.png",
  plot   = last_plot(),
  width  = 15, 
  height = 18,
  units  = "cm",
  dpi    = 600,
  limitsize = TRUE,
  bg     = "white"
)
# Out:
# Comparing communications on a single object
# plot without title

# %%
# river plot
netAnalysis_river(CellChat_T, pattern = "outgoing")
#> Please make sure you have load `library(ggalluvial)` when running this function

ggsave( 
  "River Plot Outgoing Comm anti-Her2:neu T-cells + Tumor.png",
  plot   = last_plot(),
  width  = 20, 
  height = 11,
  units  = "cm",
  dpi    = 600,
  limitsize = TRUE,
  bg     = "white"
)
# Out:
# Please make sure you have load `library(ggalluvial)` when running this function
# plot without title

# %%
# river plot
netAnalysis_river(CellChat_T, pattern = "incoming")
#> Please make sure you have load `library(ggalluvial)` when running this function

ggsave( 
  "River Plot Incoming Comm anti-Her2:neu T-cells + Tumor.png",
  plot   = last_plot(),
  width  = 20, 
  height = 11,
  units  = "cm",
  dpi    = 600,
  limitsize = TRUE,
  bg     = "white"
)
# Out:
# Please make sure you have load `library(ggalluvial)` when running this function
# plot without title

# %%
# dot plot
netAnalysis_dot(CellChat_T, pattern = "outgoing")

ggsave( 
  "Dot Outgoing Comm anti-Her2:neu T-cells + Tumor.png",
  plot   = last_plot(),
  width  = 20, 
  height = 9,
  units  = "cm",
  dpi    = 600,
  limitsize = TRUE,
  bg     = "white"
)
# Out:
# plot without title

# %%
# dot plot
netAnalysis_dot(CellChat_T, pattern = "incoming")

ggsave( 
  "Dot Incoming Comm anti-Her2:neu T-cells + Tumor.png",
  plot   = last_plot(),
  width  = 20, 
  height = 9,
  units  = "cm",
  dpi    = 600,
  limitsize = TRUE,
  bg     = "white"
)
# Out:
# plot without title
